# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# Initialize the Dash app
app = dash.Dash(__name__)

# Set the app layout
app.layout = html.Div([
    html.H1("Automobile Sales Recession and Yearly Report Dashboard")  # Meaningful title
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 44, in update_recession_report_graph(vehicle_type='Supperminicar')
#      39 @app.callback(
#      40     Output('recession-report-graph', 'figure'),
#      41     Input('vehicle-type-dropdown', 'value')
#      42 )
#      43 def update_recession_report_graph(vehicle_type):
# ---> 44     filtered_df = df[(df['Recession'] == 1) & (df['Vehicle_Type'] == vehicle_type)]
#         vehicle_type = 'Supperminicar'
#      45     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Recession Sales for {vehicle_type}')
#      46     return fig
#
# NameError: name 'df' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 45, in update_yearly_report_graph(vehicle_type='Supperminicar')
#      40 @app.callback(
#      41     Output('yearly-report-graph', 'figure'),
#      42     Input('vehicle-type-dropdown', 'value')
#      43 )
#      44 def update_yearly_report_graph(vehicle_type):
# ---> 45     filtered_df = df[df['Vehicle_Type'] == vehicle_type]
#         vehicle_type = 'Supperminicar'
#      46     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Yearly Sales for {vehicle_type}')
#      47     return fig
#
# NameError: name 'df' is not defined
#
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 44, in update_recession_report_graph(vehicle_type='Supperminicar')
#      39 @app.callback(
#      40     Output('recession-report-graph', 'figure'),
#      41     Input('vehicle-type-dropdown', 'value')
#      42 )
#      43 def update_recession_report_graph(vehicle_type):
# ---> 44     filtered_df = df[(df['Recession'] == 1) & (df['Vehicle_Type'] == vehicle_type)]
#         vehicle_type = 'Supperminicar'
#      45     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Recession Sales for {vehicle_type}')
#      46     return fig
#
# NameError: name 'df' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 45, in update_yearly_report_graph(vehicle_type='Supperminicar')
#      40 @app.callback(
#      41     Output('yearly-report-graph', 'figure'),
#      42     Input('vehicle-type-dropdown', 'value')
#      43 )
#      44 def update_yearly_report_graph(vehicle_type):
# ---> 45     filtered_df = df[df['Vehicle_Type'] == vehicle_type]
#         vehicle_type = 'Supperminicar'
#      46     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Yearly Sales for {vehicle_type}')
#      47     return fig
#
# NameError: name 'df' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 44, in update_recession_report_graph(vehicle_type='Mediumfamilycar')
#      39 @app.callback(
#      40     Output('recession-report-graph', 'figure'),
#      41     Input('vehicle-type-dropdown', 'value')
#      42 )
#      43 def update_recession_report_graph(vehicle_type):
# ---> 44     filtered_df = df[(df['Recession'] == 1) & (df['Vehicle_Type'] == vehicle_type)]
#         vehicle_type = 'Mediumfamilycar'
#      45     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Recession Sales for {vehicle_type}')
#      46     return fig
#
# NameError: name 'df' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 45, in update_yearly_report_graph(vehicle_type='Mediumfamilycar')
#      40 @app.callback(
#      41     Output('yearly-report-graph', 'figure'),
#      42     Input('vehicle-type-dropdown', 'value')
#      43 )
#      44 def update_yearly_report_graph(vehicle_type):
# ---> 45     filtered_df = df[df['Vehicle_Type'] == vehicle_type]
#         vehicle_type = 'Mediumfamilycar'
#      46     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Yearly Sales for {vehicle_type}')
#      47     return fig
#
# NameError: name 'df' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 44, in update_recession_report_graph(vehicle_type='Supperminicar')
#      39 @app.callback(
#      40     Output('recession-report-graph', 'figure'),
#      41     Input('vehicle-type-dropdown', 'value')
#      42 )
#      43 def update_recession_report_graph(vehicle_type):
# ---> 44     filtered_df = df[(df['Recession'] == 1) & (df['Vehicle_Type'] == vehicle_type)]
#         vehicle_type = 'Supperminicar'
#      45     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Recession Sales for {vehicle_type}')
#      46     return fig
#
# NameError: name 'df' is not defined
#
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 45, in update_yearly_report_graph(vehicle_type='Supperminicar')
#      40 @app.callback(
#      41     Output('yearly-report-graph', 'figure'),
#      42     Input('vehicle-type-dropdown', 'value')
#      43 )
#      44 def update_yearly_report_graph(vehicle_type):
# ---> 45     filtered_df = df[df['Vehicle_Type'] == vehicle_type]
#         vehicle_type = 'Supperminicar'
#      46     fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Yearly Sales for {vehicle_type}')
#      47     return fig
#
# NameError: name 'df' is not defined

# %%
# Adding dropdowns to the app layout
app.layout = html.Div([
    html.H1("Automobile Sales Recession and Yearly Report Dashboard"),  # Meaningful title

    html.Div([
        html.Label("Select Vehicle Type"),
        dcc.Dropdown(
            id='vehicle-type-dropdown',
            options=[
                {'label': 'Supperminicar', 'value': 'Supperminicar'},
                {'label': 'Smallfamilycar', 'value': 'Smallfamilycar'},
                {'label': 'Mediumfamilycar', 'value': 'Mediumfamilycar'},
                {'label': 'Executivecar', 'value': 'Executivecar'},
                {'label': 'Sports', 'value': 'Sports'}
            ],
            value='Supperminicar',  # Default value
            clearable=False
        ),
    ]),

    html.Div([
        html.Label("Select Year"),
        dcc.Dropdown(
            id='year-dropdown',
            options=[{'label': year, 'value': year} for year in range(1980, 2021)],
            value=2020,  # Default year
            clearable=False
        )
    ]),
])

# %%
# Add division for output
app.layout = html.Div([
    html.H1("Automobile Sales Recession and Yearly Report Dashboard"),  # Meaningful title

    html.Div([
        html.Label("Select Vehicle Type"),
        dcc.Dropdown(
            id='vehicle-type-dropdown',
            options=[
                {'label': 'Supperminicar', 'value': 'Supperminicar'},
                {'label': 'Smallfamilycar', 'value': 'Smallfamilycar'},
                {'label': 'Mediumfamilycar', 'value': 'Mediumfamilycar'},
                {'label': 'Executivecar', 'value': 'Executivecar'},
                {'label': 'Sports', 'value': 'Sports'}
            ],
            value='Supperminicar',
            clearable=False
        ),
    ]),

    html.Div([
        html.Label("Select Year"),
        dcc.Dropdown(
            id='year-dropdown',
            options=[{'label': year, 'value': year} for year in range(1980, 2021)],
            value=2020,
            clearable=False
        )
    ]),

    # Output Division
    html.Div(id='output-container', className='output-display')  # Added division for output
])

# %%
# Define callback function
@app.callback(
    Output('output-container', 'children'),
    Input('vehicle-type-dropdown', 'value'),
    Input('year-dropdown', 'value')
)
def update_output(vehicle_type, year):
    return f'You have selected {vehicle_type} for the year {year}.'

# %%
import plotly.express as px

# Add Recession Report Statistics graph in the app layout
app.layout = html.Div([
    html.H1("Automobile Sales Recession and Yearly Report Dashboard"),  # Meaningful title

    html.Div([
        html.Label("Select Vehicle Type"),
        dcc.Dropdown(
            id='vehicle-type-dropdown',
            options=[
                {'label': 'Supperminicar', 'value': 'Supperminicar'},
                {'label': 'Smallfamilycar', 'value': 'Smallfamilycar'},
                {'label': 'Mediumfamilycar', 'value': 'Mediumfamilycar'},
                {'label': 'Executivecar', 'value': 'Executivecar'},
                {'label': 'Sports', 'value': 'Sports'}
            ],
            value='Supperminicar',
            clearable=False
        ),
    ]),

    html.Div([
        html.Label("Select Year"),
        dcc.Dropdown(
            id='year-dropdown',
            options=[{'label': year, 'value': year} for year in range(1980, 2021)],
            value=2020,
            clearable=False
        )
    ]),

    html.Div(id='output-container', className='output-display'),

    # Graph for Recession Report Statistics
    dcc.Graph(id='recession-report-graph')  # Added graph component
])

@app.callback(
    Output('recession-report-graph', 'figure'),
    Input('vehicle-type-dropdown', 'value')
)
def update_recession_report_graph(vehicle_type):
    filtered_df = df[(df['Recession'] == 1) & (df['Vehicle_Type'] == vehicle_type)]
    fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Recession Sales for {vehicle_type}')
    return fig

# %%
# Graph for Yearly Report Statistics
app.layout = html.Div([
    html.H1("Automobile Sales Recession and Yearly Report Dashboard"),  # Meaningful title

    html.Div([
        html.Label("Select Vehicle Type"),
        dcc.Dropdown(
            id='vehicle-type-dropdown',
            options=[
                {'label': 'Supperminicar', 'value': 'Supperminicar'},
                {'label': 'Smallfamilycar', 'value': 'Smallfamilycar'},
                {'label': 'Mediumfamilycar', 'value': 'Mediumfamilycar'},
                {'label': 'Executivecar', 'value': 'Executivecar'},
                {'label': 'Sports', 'value': 'Sports'}
            ],
            value='Supperminicar',
            clearable=False
        ),
    ]),

    html.Div([
        html.Label("Select Year"),
        dcc.Dropdown(
            id='year-dropdown',
            options=[{'label': year, 'value': year} for year in range(1980, 2021)],
            value=2020,
            clearable=False
        )
    ]),

    html.Div(id='output-container', className='output-display'),

    # Recession Report Graph
    dcc.Graph(id='recession-report-graph'),

    # Yearly Report Graph
    dcc.Graph(id='yearly-report-graph')  # Added Yearly Report Graph
])

@app.callback(
    Output('yearly-report-graph', 'figure'),
    Input('vehicle-type-dropdown', 'value')
)
def update_yearly_report_graph(vehicle_type):
    filtered_df = df[df['Vehicle_Type'] == vehicle_type]
    fig = px.line(filtered_df, x='Year', y='Automobile_Sales', title=f'Yearly Sales for {vehicle_type}')
    return fig
